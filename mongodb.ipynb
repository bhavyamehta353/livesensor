# %%
import pymongo
from pymongo import MongoClient

# %%
connection_string = "mongodb+srv://bhavyamehta353_db_user:w9TGmBlduoeDMba4@cluster0.imbl63g.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
client = MongoClient(connection_string)

# %%
db = client["livesensor"]
collection = db["mongoclass"]

# %%
temp_data = {
    "name": "Bhavya Mehta",
    "age": 20,
    "email": "bhavyamehta353@gmail.com"
}

# %%
collection.insert_one(temp_data)

# %%
temp = collection .find({})
for i in temp:
    print(i)
# Out:
# {'_id': ObjectId('68f0e07b9e2b4ba7752a4d33'), 'name': 'Bhavya Mehta', 'age': 20, 'email': 'bhavyamehta353@gmail.com'}
